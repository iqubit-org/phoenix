# %%
import phoenix
import json

# %%
with open('./benchmarks/qaoa_json/qaoa_rand_24.json') as f:
    data = json.load(f)

grouped_paulis = phoenix.primitive.group_paulis(data['paulis'])

# %%
len(data['paulis'])
# Out:
# 48

# %%
grouped_paulis
# Out:
# {(np.int64(0), np.int64(5)): ['ZIIIIZIIIIIIIIIIIIIIIIII'],
#  (np.int64(1), np.int64(10)): ['IZIIIIIIIIZIIIIIIIIIIIII'],
#  (np.int64(2), np.int64(3)): ['IIZZIIIIIIIIIIIIIIIIIIII'],
#  (np.int64(4), np.int64(11)): ['IIIIZIIIIIIZIIIIIIIIIIII'],
#  (np.int64(6), np.int64(7)): ['IIIIIIZZIIIIIIIIIIIIIIII'],
#  (np.int64(9), np.int64(14)): ['IIIIIIIIIZIIIIZIIIIIIIII'],
#  (np.int64(12), np.int64(15)): ['IIIIIIIIIIIIZIIZIIIIIIII'],
#  (np.int64(13), np.int64(18)): ['IIIIIIIIIIIIIZIIIIZIIIII'],
#  (np.int64(16), np.int64(17)): ['IIIIIIIIIIIIIIIIZZIIIIII'],
#  (np.int64(19), np.int64(20)): ['IIIIIIIIIIIIIIIIIIIZZIII'],
#  (np.int64(21), np.int64(22)): ['IIIIIIIIIIIIIIIIIIIIIZZI'],
#  (np.int64(0), np.int64(8)): ['ZIIIIIIIZIIIIIIIIIIIIIII'],
#  (np.int64(16), np.int64(23)): ['IIIIIIIIIIIIIIIIZIIIIIIZ'],
#  (np.int64(1), np.int64(5)): ['IZIIIZIIIIIIIIIIIIIIIIII'],
#  (np.int64(2), np.int64(10)): ['IIZIIIIIIIZIIIIIIIIIIIII'],
#  (np.int64(3), np.int64(22)): ['IIIZIIIIIIIIIIIIIIIIIIZI'],
# ...
