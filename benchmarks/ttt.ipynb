# %%
import qiskit
import h5py

# %%
file_path = 'FH_D-1.hdf5'

with h5py.File(file_path, 'r') as file:
    # 查看文件中的所有组
    print("Groups in HDF5 file:")
    for group in file.keys():
        print(group)

    # # 读取数据集
    # dataset_name = 'dataset_name'
    # dataset = file[dataset_name][()]  # 注意加上[()]来获取数据集的值

    # # 打印数据集的形状和内容
    # print(f"Shape of dataset '{dataset_name}': {dataset.shape}")
    # print(f"Data in dataset '{dataset_name}':")
    # print(dataset)
# Out:
# Groups in HDF5 file:
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-0_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-0_enc-jw
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-0_enc-parity
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-12_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-12_enc-jw
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-12_enc-parity
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-2_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-2_enc-jw
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-2_enc-parity
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-4_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-4_enc-jw
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-4_enc-parity
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-6_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-6_enc-jw
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-6_enc-parity
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-8_enc-bk
# fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-8_enc-jw
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 file['fh-graph-1D-grid-nonpbc-qubitnodes_Lx-1000_U-0_enc-bk']
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/lib/python3.12/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# ...
