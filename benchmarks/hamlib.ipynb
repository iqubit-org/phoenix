# %%
import json
import matplotlib.pyplot as plt
from collections import Counter

# %%
with open('100_representative.json', 'r') as f:
    data = json.load(f)

# %%
data[0]
# Out:
# {'ham_category': 'chemistry',
#  'ham_primary_type': 'vibrational',
#  'ham_problem': 'all-vib-bh',
#  'ham_instance': '/enc_stdbinary_dvalues_d-level-4,',
#  'ham_qubits': 2,
#  'ham_terms': 10,
#  'ham_hamlib_hamiltonian_terms': ['II',
#   'XI',
#   'XX',
#   'XZ',
#   'YY',
#   'ZI',
#   'ZX',
#   'ZZ',
#   'IX',
#   'IZ'],
#  'ham_hamlib_hamiltonian_coefficients': [20373.41697885077,
#   -5610.850433196509,
#   -3300.6163111809255,
#   3799.7747686809635,
#   -1821.8792233025738,
#   -6337.2311195820985,
#   -2655.1988246136793,
#   1990.202999791049,
#   5469.7708987937995,
#   -12674.462239164197]}

# %%
# Counter [ham['ham_category'] for ham in data] and plot a bar chart
from collections import Counter
ham_categories = [ham['ham_category'] for ham in data]
ham_categories_counter = Counter(ham_categories)

plt.figure(figsize=(8, 3))

plt.bar(ham_categories_counter.keys(), ham_categories_counter.values())
plt.title('Ham Categories')
plt.show()

# %%
# Counter [ham['ham_qubits'] for ham in data] and plot a bar chart
ham_qubits = [ham['ham_qubits'] for ham in data if ham['ham_category'] == 'discreteoptimization']
ham_qubits_counter = Counter(ham_qubits)

plt.figure(figsize=(8, 3))
plt.bar(ham_qubits_counter.keys(), ham_qubits_counter.values())
plt.title('Ham Qubits')
plt.show()

# %%
# Counter [ham['ham_qubits'] for ham in data] and plot a bar chart
ham_qubits = [ham['ham_qubits'] for ham in data if ham['ham_category'] == 'discreteoptimization']
ham_qubits_counter = Counter(ham_qubits)

plt.figure(figsize=(8, 3))
plt.bar(ham_qubits_counter.keys(), ham_qubits_counter.values())
plt.title('Ham Qubits')
plt.show()

# %%
# Counter [ham['ham_qubits'] for ham in data] and plot a bar chart
ham_qubits = [ham['ham_qubits'] for ham in data if ham['ham_category'] == 'chemistry']
ham_qubits_counter = Counter(ham_qubits)

plt.figure(figsize=(8, 3))
plt.bar(ham_qubits_counter.keys(), ham_qubits_counter.values())
plt.title('Ham Qubits')
plt.show()

# %%
# Counter [ham['ham_qubits'] for ham in data] and plot a bar chart
ham_qubits = [ham['ham_qubits'] for ham in data if ham['ham_category'] == 'condensedmatter']
ham_qubits_counter = Counter(ham_qubits)

plt.figure(figsize=(8, 3))
plt.bar(ham_qubits_counter.keys(), ham_qubits_counter.values())
plt.title('Ham Qubits')
plt.show()

# %%
max(ham_qubits_counter.keys())
# Out:
# 930

# %%
# Counter [ham['ham_terms'] for ham in data] and plot a bar chart
ham_terms = [ham['ham_terms'] for ham in data if ham['ham_category'] == 'chemistry']
ham_terms_counter = Counter(ham_terms)

plt.figure(figsize=(8, 3))
plt.bar(ham_terms_counter.keys(), ham_terms_counter.values())
plt.title('Ham Terms')
plt.show()

# %%
ham_terms_counter
# Out:
# Counter({10: 1,
#          12: 1,
#          6: 1,
#          8: 1,
#          27: 1,
#          32: 2,
#          99: 1,
#          24: 1,
#          62: 1,
#          14: 1,
#          185: 1,
#          2802: 1,
#          276: 3,
#          40: 1,
#          18: 1,
#          631: 3,
#          1789: 1,
#          670: 2,
#          1036: 1,
#          1086: 2,
#          30: 1,
#          1884: 1,
#          4578: 1,
#          5466: 1,
#          48: 1,
#          6509: 1,
#          60: 1,
#          120: 1})

# %%
data[0]
# Out:
# {'ham_category': 'chemistry',
#  'ham_primary_type': 'vibrational',
#  'ham_problem': 'all-vib-bh',
#  'ham_instance': '/enc_stdbinary_dvalues_d-level-4,',
#  'ham_qubits': 2,
#  'ham_terms': 10,
#  'ham_hamlib_hamiltonian_terms': ['II',
#   'XI',
#   'XX',
#   'XZ',
#   'YY',
#   'ZI',
#   'ZX',
#   'ZZ',
#   'IX',
#   'IZ'],
#  'ham_hamlib_hamiltonian_coefficients': [20373.41697885077,
#   -5610.850433196509,
#   -3300.6163111809255,
#   3799.7747686809635,
#   -1821.8792233025738,
#   -6337.2311195820985,
#   -2655.1988246136793,
#   1990.202999791049,
#   5469.7708987937995,
#   -12674.462239164197]}

# %%
for ham in data:
    print(ham['ham_category'], ham['ham_problem'], ham['ham_instance'], ham['ham_qubits'])
# Out:
# chemistry all-vib-bh /enc_stdbinary_dvalues_d-level-4, 2
# chemistry all-vib-c2h /mu_y_prime_enc_stdbinary_dvalues_8-8-4-4, 3
# chemistry all-vib-o3 /mu_y_prime_enc_unary_dvalues_4-4-4, 4
# chemistry all-vib-c2h /mu_z_prime_enc_gray_dvalues_4-4-4-4, 4
# binaryoptimization graph-gnp_k-2 /gnp-k_2_n-4_rinst-05, 4
# chemistry LiH /ham_parity-4, 4
# chemistry all-vib-fccf /mu_y_prime_enc_stdbinary_dvalues_16-16-16-16-8-8-8, 4
# chemistry all-vib-ch2 /mu_y_prime_enc_gray_dvalues_16-16-16, 4
# chemistry all-vib-f2 /enc_gray_dvalues_d-level-16, 4
# chemistry all-vib-bhf2 /mu_y_prime_enc_stdbinary_dvalues_8-8-8-8-8-8, 6
# binaryoptimization graph-gnp_k-4 /gnp-k_4_n-6_rinst-15, 6
# chemistry Be2 /ham_JW-6, 6
# chemistry all-vib-fccf /mu_y_prime_enc_unary_dvalues_8-8-8-8-8-8-8, 8
# binaryoptimization uf20-ham /7-uf20-0384.cnf-8-res, 8
# discreteoptimization TSP_Ncity-4 /tsp_rand-002_Ncity-4_enc-stdbinary, 8
# chemistry H2 /ham_JW-8, 8
# chemistry all-vib-o3 /enc_gray_dvalues_8-8-8, 9
# ...
