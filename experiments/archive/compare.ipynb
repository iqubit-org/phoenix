# %%
import os
import cirq
import qiskit
import pytket
import pytket.qasm
import pytket.passes
import numpy as np
from qiskit.quantum_info import Operator
from natsort import natsorted

import matplotlib.pyplot as plt

# %%
def geometric_mean(arr):
    return np.prod(arr) ** (1 / len(arr))

# %% [markdown]
# ### Opt all2all

# %%
input_dpath = '../benchmarks/uccsd_qasm'

# %%
fnames = natsorted(os.listdir(input_dpath))

num_2q_gates_original = []
depth_2q_original = []
for fname in fnames:
    fname = os.path.join(input_dpath, fname)
    circ = qiskit.QuantumCircuit.from_qasm_file(fname)
    num_2q_gates_original.append(circ.num_nonlocal_gates())
    depth_2q_original.append(circ.depth(lambda instr: instr.operation.num_qubits > 1))

fnames_qiskit = [os.path.join('./qiskit_opt', fname) for fname in fnames]
fnames_tket = [fname.replace('qiskit_opt', 'tket_opt') for fname in fnames_qiskit]

# %%
num_2q_gates_qiskit = []
num_2q_gates_tket = []
depth_2q_qiskit = []
depth_2q_tket = []

for fname in fnames:
    fname_qiskit = os.path.join('./qiskit_opt', fname)
    fname_tket = fname_qiskit.replace('qiskit_opt', 'tket_opt')

    circ_qiskit = qiskit.QuantumCircuit.from_qasm_file(fname_qiskit)
    circ_tket = qiskit.QuantumCircuit.from_qasm_file(fname_tket)

    print(f'fname: {fname}')
    print('#gates\t {}\t {}'.format(circ_qiskit.size(), circ_tket.size()))
    print('depth\t {}\t {}'.format(circ_qiskit.depth(), circ_tket.depth()))
    print('#2Q\t {}\t {}'.format(circ_qiskit.num_nonlocal_gates(), circ_tket.num_nonlocal_gates()))
    print('dep(2q)\t {}\t {}'.format(
        circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1),
        circ_tket.depth(lambda intr: intr.operation.num_qubits > 1)
    ))
    num_2q_gates_qiskit.append(circ_qiskit.num_nonlocal_gates())
    num_2q_gates_tket.append(circ_tket.num_nonlocal_gates())
    depth_2q_qiskit.append(circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1))
    depth_2q_tket.append(circ_tket.depth(lambda intr: intr.operation.num_qubits > 1))
# Out:
# fname: CH2_cmplt_BK_sto3g.qasm
# #gates	 20792	 20293
# depth	 17406	 16843
# #2Q	 14008	 12306
# dep(2q)	 13954	 12140
# fname: CH2_cmplt_JW_sto3g.qasm
# #gates	 22291	 19639
# depth	 17199	 15142
# #2Q	 14303	 11716
# dep(2q)	 13414	 11095
# fname: CH2_cmplt_P_sto3g.qasm
# #gates	 21532	 20891
# depth	 18356	 18636
# #2Q	 15259	 14585
# dep(2q)	 15204	 14525
# fname: CH2_frz_BK_sto3g.qasm
# #gates	 11597	 11442
# depth	 9712	 9530
# #2Q	 7819	 6968
# dep(2q)	 7801	 6874
# fname: CH2_frz_JW_sto3g.qasm
# #gates	 11618	 10084
# depth	 8800	 7617
# #2Q	 7098	 5700
# dep(2q)	 6644	 5379
# fname: CH2_frz_P_sto3g.qasm
# #gates	 11075	 10728
# depth	 9315	 9457
# #2Q	 7610	 7228
# dep(2q)	 7565	 7180
# fname: H2O_cmplt_BK_sto3g.qasm
# #gates	 13970	 14021
# depth	 11678	 11663
# #2Q	 9561	 8630
# dep(2q)	 9508	 8537
# fname: H2O_cmplt_JW_sto3g.qasm
# #gates	 15031	 13150
# depth	 11770	 10301
# #2Q	 9712	 7950
# dep(2q)	 9214	 7614
# fname: H2O_cmplt_P_sto3g.qasm
# #gates	 14492	 13985
# depth	 12406	 12541
# #2Q	 10342	 9881
# dep(2q)	 10281	 9824
# fname: H2O_frz_BK_sto3g.qasm
# #gates	 8590	 8563
# depth	 7191	 7020
# #2Q	 5834	 5090
# dep(2q)	 5816	 5012
# fname: H2O_frz_JW_sto3g.qasm
# #gates	 8978	 7732
# depth	 6871	 5912
# #2Q	 5495	 4420
# dep(2q)	 5194	 4212
# fname: H2O_frz_P_sto3g.qasm
# #gates	 8539	 8229
# depth	 7209	 7290
# #2Q	 5908	 5611
# dep(2q)	 5856	 5561
# fname: LiH_cmplt_BK_sto3g.qasm
# #gates	 9959	 9947
# depth	 8501	 8409
# #2Q	 7084	 6314
# dep(2q)	 7073	 6278
# fname: LiH_cmplt_JW_sto3g.qasm
# #gates	 9073	 7912
# depth	 6922	 5989
# #2Q	 5593	 4488
# dep(2q)	 5245	 4228
# fname: LiH_cmplt_P_sto3g.qasm
# #gates	 8614	 8346
# depth	 7238	 7325
# #2Q	 5916	 5603
# dep(2q)	 5879	 5565
# fname: LiH_frz_BK_sto3g.qasm
# #gates	 1766	 1616
# depth	 1482	 1358
# #2Q	 1161	 1031
# dep(2q)	 1157	 1010
# fname: LiH_frz_JW_sto3g.qasm
# #gates	 1871	 1655
# depth	 1491	 1282
# #2Q	 1158	 916
# dep(2q)	 1127	 885
# fname: LiH_frz_P_sto3g.qasm
# #gates	 1766	 1707
# depth	 1461	 1462
# #2Q	 1161	 1077
# dep(2q)	 1151	 1062
# fname: NH_cmplt_BK_sto3g.qasm
# #gates	 8590	 8563
# depth	 7191	 7020
# #2Q	 5834	 5090
# dep(2q)	 5816	 5012
# fname: NH_cmplt_JW_sto3g.qasm
# #gates	 8978	 7732
# depth	 6871	 5912
# #2Q	 5495	 4420
# dep(2q)	 5194	 4212
# fname: NH_cmplt_P_sto3g.qasm
# #gates	 8539	 8229
# depth	 7209	 7290
# #2Q	 5908	 5611
# dep(2q)	 5856	 5561
# fname: NH_frz_BK_sto3g.qasm
# #gates	 4959	 4873
# depth	 4179	 4080
# #2Q	 3366	 2975
# dep(2q)	 3355	 2956
# fname: NH_frz_JW_sto3g.qasm
# #gates	 4598	 3950
# depth	 3488	 2931
# #2Q	 2758	 2106
# dep(2q)	 2602	 1993
# fname: NH_frz_P_sto3g.qasm
# #gates	 4369	 4202
# depth	 3616	 3658
# #2Q	 2905	 2737
# dep(2q)	 2863	 2696

# %%
plt.figure(figsize=(15, 5))
width = 0.4
plt.bar(np.arange(len(fnames)), num_2q_gates_qiskit, width, label='qiskit')
plt.bar(np.arange(len(fnames)) + width, num_2q_gates_tket, width, label='tket')
plt.xlim(-0.5, len(fnames))
plt.xticks(np.arange(len(fnames)), [fname.split('.')[0] for fname in fnames], rotation=45, fontsize=7, fontweight='bold')
plt.legend()
plt.tight_layout()

# %%
geometric_mean(np.array(num_2q_gates_qiskit) / np.array(num_2q_gates_original)), geometric_mean(np.array(num_2q_gates_tket) / np.array(num_2q_gates_original))
# Out:
# (0.7379117660787283, 0.6460552466899815)

# %%
geometric_mean(np.array(depth_2q_qiskit) / np.array(depth_2q_original)), geometric_mean(np.array(depth_2q_tket) / np.array(depth_2q_original))
# Out:
# (0.7382980349233704, 0.6453368081918247)

# %% [markdown]
# ### Post-Opt all2all

# %%
input_dpath = './output_uccsd/phoenix/all2all'

# %%
fnames = natsorted(os.listdir(input_dpath))

num_2q_gates_original = []
depth_2q_original = []
for fname in fnames:
    fname = os.path.join(input_dpath, fname)
    circ = qiskit.QuantumCircuit.from_qasm_file(fname)
    num_2q_gates_original.append(circ.num_nonlocal_gates())
    depth_2q_original.append(circ.depth(lambda instr: instr.operation.num_qubits > 1))


fnames_qiskit = [os.path.join('./qiskit_post_opt', fname) for fname in fnames]
fnames_tket = [fname.replace('qiskit_post_opt', 'tket_post_opt') for fname in fnames_qiskit]

# %%
num_2q_gates_qiskit = []
num_2q_gates_tket = []
depth_2q_qiskit = []
depth_2q_tket = []

for fname in fnames:
    fname_qiskit = os.path.join('./qiskit_post_opt', fname)
    fname_tket = fname_qiskit.replace('qiskit_post_opt', 'tket_post_opt')

    circ_qiskit = qiskit.QuantumCircuit.from_qasm_file(fname_qiskit)
    circ_tket = qiskit.QuantumCircuit.from_qasm_file(fname_tket)

    print(f'fname: {fname}')
    print('#gates\t {}\t {}'.format(circ_qiskit.size(), circ_tket.size()))
    print('depth\t {}\t {}'.format(circ_qiskit.depth(), circ_tket.depth()))
    print('#2Q\t {}\t {}'.format(circ_qiskit.num_nonlocal_gates(), circ_tket.num_nonlocal_gates()))
    print('dep(2q)\t {}\t {}'.format(
        circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1),
        circ_tket.depth(lambda intr: intr.operation.num_qubits > 1)
    ))
    num_2q_gates_qiskit.append(circ_qiskit.num_nonlocal_gates())
    num_2q_gates_tket.append(circ_tket.num_nonlocal_gates())
    depth_2q_qiskit.append(circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1))
    depth_2q_tket.append(circ_tket.depth(lambda intr: intr.operation.num_qubits > 1))
# Out:
# fname: CH2_cmplt_BK_sto3g.qasm
# #gates	 9195	 8391
# depth	 6153	 5507
# #2Q	 4304	 3996
# dep(2q)	 3710	 3394
# fname: CH2_cmplt_JW_sto3g.qasm
# #gates	 9089	 8833
# depth	 5878	 5416
# #2Q	 4304	 4099
# dep(2q)	 3599	 3443
# fname: CH2_cmplt_P_sto3g.qasm
# #gates	 10763	 9793
# depth	 7033	 6253
# #2Q	 5525	 4895
# dep(2q)	 4709	 4059
# fname: CH2_frz_BK_sto3g.qasm
# #gates	 4964	 4552
# depth	 3342	 3022
# #2Q	 2338	 2168
# dep(2q)	 2021	 1861
# fname: CH2_frz_JW_sto3g.qasm
# #gates	 4881	 4738
# depth	 3163	 2917
# #2Q	 2227	 2111
# dep(2q)	 1881	 1792
# fname: CH2_frz_P_sto3g.qasm
# #gates	 5680	 5196
# depth	 3717	 3298
# #2Q	 2822	 2519
# dep(2q)	 2391	 2062
# fname: H2O_cmplt_BK_sto3g.qasm
# #gates	 6349	 5852
# depth	 4258	 3867
# #2Q	 3003	 2793
# dep(2q)	 2584	 2385
# fname: H2O_cmplt_JW_sto3g.qasm
# #gates	 6101	 5918
# depth	 3998	 3680
# #2Q	 2889	 2749
# dep(2q)	 2434	 2330
# fname: H2O_cmplt_P_sto3g.qasm
# #gates	 8083	 7357
# depth	 5287	 4732
# #2Q	 4237	 3746
# dep(2q)	 3588	 3123
# fname: H2O_frz_BK_sto3g.qasm
# #gates	 3276	 2846
# depth	 2111	 1841
# #2Q	 1440	 1290
# dep(2q)	 1211	 1082
# fname: H2O_frz_JW_sto3g.qasm
# #gates	 3797	 3673
# depth	 2475	 2280
# #2Q	 1737	 1645
# dep(2q)	 1469	 1400
# fname: H2O_frz_P_sto3g.qasm
# #gates	 4876	 4503
# depth	 3188	 2909
# #2Q	 2471	 2221
# dep(2q)	 2093	 1867
# fname: LiH_cmplt_BK_sto3g.qasm
# #gates	 3401	 2963
# depth	 2314	 1978
# #2Q	 1523	 1368
# dep(2q)	 1316	 1178
# fname: LiH_cmplt_JW_sto3g.qasm
# #gates	 3750	 3641
# depth	 2446	 2258
# #2Q	 1702	 1613
# dep(2q)	 1449	 1384
# fname: LiH_cmplt_P_sto3g.qasm
# #gates	 4455	 4026
# depth	 2929	 2628
# #2Q	 2227	 1960
# dep(2q)	 1898	 1651
# fname: LiH_frz_BK_sto3g.qasm
# #gates	 961	 906
# depth	 710	 660
# #2Q	 448	 418
# dep(2q)	 416	 382
# fname: LiH_frz_JW_sto3g.qasm
# #gates	 834	 782
# depth	 555	 509
# #2Q	 363	 342
# dep(2q)	 320	 306
# fname: LiH_frz_P_sto3g.qasm
# #gates	 1092	 982
# depth	 771	 665
# #2Q	 531	 469
# dep(2q)	 485	 421
# fname: NH_cmplt_BK_sto3g.qasm
# #gates	 3276	 2846
# depth	 2111	 1841
# #2Q	 1440	 1290
# dep(2q)	 1211	 1082
# fname: NH_cmplt_JW_sto3g.qasm
# #gates	 3797	 3673
# depth	 2475	 2280
# #2Q	 1737	 1645
# dep(2q)	 1469	 1400
# fname: NH_cmplt_P_sto3g.qasm
# #gates	 4876	 4503
# depth	 3188	 2909
# #2Q	 2471	 2221
# dep(2q)	 2093	 1867
# fname: NH_frz_BK_sto3g.qasm
# #gates	 2317	 2143
# depth	 1607	 1471
# #2Q	 1065	 1001
# dep(2q)	 950	 887
# fname: NH_frz_JW_sto3g.qasm
# #gates	 2053	 1983
# depth	 1335	 1230
# #2Q	 900	 846
# dep(2q)	 770	 731
# fname: NH_frz_P_sto3g.qasm
# #gates	 2506	 2267
# depth	 1660	 1458
# #2Q	 1209	 1076
# dep(2q)	 1027	 896

# %%
plt.figure(figsize=(15, 5))
width = 0.4
plt.bar(np.arange(len(fnames)), num_2q_gates_qiskit, width, label='qiskit')
plt.bar(np.arange(len(fnames)) + width, num_2q_gates_tket, width, label='tket')

plt.xlim(-0.5, len(fnames))
plt.xticks(np.arange(len(fnames)), [fname.split('.')[0] for fname in fnames], rotation=45, fontsize=7, fontweight='bold')
plt.legend()
plt.tight_layout()

# %%
geometric_mean(np.array(num_2q_gates_qiskit) / np.array(num_2q_gates_original)), geometric_mean(np.array(num_2q_gates_tket) / np.array(num_2q_gates_original))
# Out:
# (0.8587995068437994, 0.7882789018690608)

# %%
geometric_mean(np.array(depth_2q_qiskit) / np.array(depth_2q_original)), geometric_mean(np.array(depth_2q_tket) / np.array(depth_2q_original))
# Out:
# (0.8387992728506238, 0.7653871950996425)

# %% [markdown]
# ### Post-Opt Manhattan

# %%
input_dpath = './output_uccsd/phoenix/all2all'

# %%
fnames = natsorted(os.listdir(input_dpath))

num_2q_gates_original = []
depth_2q_original = []
for fname in fnames:
    fname = os.path.join(input_dpath, fname)
    circ = qiskit.QuantumCircuit.from_qasm_file(fname)
    num_2q_gates_original.append(circ.num_nonlocal_gates())
    depth_2q_original.append(circ.depth(lambda instr: instr.operation.num_qubits > 1))


fnames_qiskit = [os.path.join('./qiskit_post_opt_manhattan', fname) for fname in fnames]
fnames_tket = [fname.replace('qiskit_post_opt_manhattan', 'tket_post_opt_manhattan') for fname in fnames_qiskit]

# %%
num_2q_gates_qiskit = []
num_2q_gates_tket = []
depth_2q_qiskit = []
depth_2q_tket = []

for fname in fnames:
    fname_qiskit = os.path.join('./qiskit_post_opt_manhattan', fname)
    fname_tket = fname_qiskit.replace('qiskit_post_opt_manhattan', 'tket_post_opt_manhattan')

    try:
        circ_qiskit = qiskit.QuantumCircuit.from_qasm_file(fname_qiskit)
        circ_tket = qiskit.QuantumCircuit.from_qasm_file(fname_tket)
    except:
        continue

    print(f'fname: {fname}')
    # print('#gates\t {}\t {}'.format(circ_qiskit.size(), circ_tket.size()))
    # print('depth\t {}\t {}'.format(circ_qiskit.depth(), circ_tket.depth()))
    print('#2Q\t {}\t {}'.format(circ_qiskit.num_nonlocal_gates(), circ_tket.num_nonlocal_gates()))
    print('dep(2q)\t {}\t {}'.format(
        circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1),
        circ_tket.depth(lambda intr: intr.operation.num_qubits > 1)
    ))
    num_2q_gates_qiskit.append(circ_qiskit.num_nonlocal_gates())
    num_2q_gates_tket.append(circ_tket.num_nonlocal_gates())
    depth_2q_qiskit.append(circ_qiskit.depth(lambda intr: intr.operation.num_qubits > 1))
    depth_2q_tket.append(circ_tket.depth(lambda intr: intr.operation.num_qubits > 1))
# Out:
# fname: CH2_cmplt_BK_sto3g.qasm
# #2Q	 12632	 13200
# dep(2q)	 8865	 8936
# fname: CH2_cmplt_JW_sto3g.qasm
# #2Q	 15359	 13938
# dep(2q)	 10498	 9165
# fname: CH2_cmplt_P_sto3g.qasm
# #2Q	 21350	 17627
# dep(2q)	 13911	 11343
# fname: CH2_frz_BK_sto3g.qasm
# #2Q	 6249	 6505
# dep(2q)	 4654	 4716
# fname: CH2_frz_JW_sto3g.qasm
# #2Q	 7129	 6505
# dep(2q)	 5204	 4572
# fname: CH2_frz_P_sto3g.qasm
# #2Q	 8270	 8185
# dep(2q)	 5804	 5668
# fname: H2O_cmplt_BK_sto3g.qasm
# #2Q	 8980	 9407
# dep(2q)	 6302	 6303
# fname: H2O_cmplt_JW_sto3g.qasm
# #2Q	 10090	 9247
# dep(2q)	 7176	 6243
# fname: H2O_cmplt_P_sto3g.qasm
# #2Q	 15406	 13963
# dep(2q)	 9788	 8743
# fname: H2O_frz_BK_sto3g.qasm
# #2Q	 3949	 3760
# dep(2q)	 3016	 2747
# fname: H2O_frz_JW_sto3g.qasm
# #2Q	 5402	 4909
# dep(2q)	 4040	 3667
# fname: H2O_frz_P_sto3g.qasm
# #2Q	 7221	 7182
# dep(2q)	 4948	 5007
# fname: LiH_cmplt_BK_sto3g.qasm
# #2Q	 3910	 3609
# dep(2q)	 3093	 2754
# fname: LiH_cmplt_JW_sto3g.qasm
# #2Q	 5437	 4889
# dep(2q)	 4088	 3561
# fname: LiH_cmplt_P_sto3g.qasm
# #2Q	 6310	 6126
# dep(2q)	 4423	 4330
# fname: LiH_frz_BK_sto3g.qasm
# #2Q	 743	 983
# dep(2q)	 620	 808
# fname: LiH_frz_JW_sto3g.qasm
# #2Q	 1066	 849
# dep(2q)	 875	 708
# fname: LiH_frz_P_sto3g.qasm
# #2Q	 1311	 1227
# dep(2q)	 997	 946
# fname: NH_cmplt_BK_sto3g.qasm
# #2Q	 3591	 3526
# dep(2q)	 2754	 2679
# fname: NH_cmplt_JW_sto3g.qasm
# #2Q	 5632	 5070
# dep(2q)	 4144	 3663
# fname: NH_cmplt_P_sto3g.qasm
# #2Q	 7550	 7194
# dep(2q)	 5319	 4974
# fname: NH_frz_BK_sto3g.qasm
# #2Q	 2458	 2751
# dep(2q)	 1930	 2130
# fname: NH_frz_JW_sto3g.qasm
# #2Q	 2500	 2370
# dep(2q)	 1900	 1826
# fname: NH_frz_P_sto3g.qasm
# #2Q	 2905	 3132
# dep(2q)	 2139	 2308

# %%
plt.figure(figsize=(15, 5))
width = 0.4
plt.bar(np.arange(len(fnames)), num_2q_gates_qiskit, width, label='qiskit')
plt.bar(np.arange(len(fnames)) + width, num_2q_gates_tket, width, label='tket')

plt.xlim(-0.5, len(fnames))
plt.xticks(np.arange(len(fnames)), [fname.split('.')[0] for fname in fnames], rotation=45, fontsize=7, fontweight='bold')
plt.legend()
plt.tight_layout()

# %%
geometric_mean(np.array(num_2q_gates_qiskit) / np.array(num_2q_gates_original)), geometric_mean(np.array(num_2q_gates_tket) / np.array(num_2q_gates_original))
# Out:
# (2.4694905521501562, 2.3822805683664923)

# %%
geometric_mean(np.array(depth_2q_qiskit) / np.array(depth_2q_original)), geometric_mean(np.array(depth_2q_tket) / np.array(depth_2q_original))
# Out:
# (2.056643758602344, 1.9514354673006766)

# %%
num_2q_gates_qiskit = []
num_2q_gates_qiskit_opt = []
num_2q_gates_tket = []
num_2q_gates_tket2 = []
num_2q_gates_tket3 = []
depth_2q_qiskit = []
depth_2q_qiskit_opt = []
depth_2q_tket = []
depth_2q_tket2 = []
depth_2q_tket3 = []

fnames = natsorted(os.listdir('qiskit_post_opt_manhattan_opt'))
for fname in fnames:
    print(f'fname: {fname}')
    fname_qiskit = os.path.join('qiskit_post_opt_manhattan', fname)
    fname_qiskit_opt = os.path.join('qiskit_post_opt_manhattan_opt', fname)
    fname_tket = os.path.join('tket_post_opt_manhattan', fname)
    fname_tket2 = os.path.join('tket_post_opt_manhattan2', fname)
    fname_tket3 = os.path.join('tket_post_opt_manhattan3', fname)

    circ_qiskit = qiskit.QuantumCircuit.from_qasm_file(fname_qiskit)
    circ_qiskit_opt = qiskit.QuantumCircuit.from_qasm_file(fname_qiskit_opt)
    circ_tket = qiskit.QuantumCircuit.from_qasm_file(fname_tket)
    circ_tket2 = qiskit.QuantumCircuit.from_qasm_file(fname_tket2)
    circ_tket3 = qiskit.QuantumCircuit.from_qasm_file(fname_tket3)

    # print('#gates\t {}\t {}'.format(circ_tket.size(), circ_tket2.size()))
    # print('depth\t {}\t {}'.format(circ_tket.depth(), circ_tket2.depth()))
    print('#2Q\t {}\t {}\t {}\t {}\t {}'.format(
        circ_qiskit.num_nonlocal_gates(),
        circ_qiskit_opt.num_nonlocal_gates(),
        circ_tket.num_nonlocal_gates(),
        circ_tket2.num_nonlocal_gates(),
        circ_tket3.num_nonlocal_gates()))
    print('dep(2q)\t {}\t {}\t {}\t {}\t {}'.format(
        circ_qiskit.depth(lambda instr: instr.operation.num_qubits > 1),
        circ_qiskit_opt.depth(lambda instr: instr.operation.num_qubits > 1),
        circ_tket2.depth(lambda intr: intr.operation.num_qubits > 1),
        circ_tket2.depth(lambda intr: intr.operation.num_qubits > 1),
        circ_tket3.depth(lambda intr: intr.operation.num_qubits > 1)
    ))

    num_2q_gates_qiskit.append(circ_qiskit.num_nonlocal_gates())
    num_2q_gates_qiskit_opt.append(circ_qiskit_opt.num_nonlocal_gates())
    num_2q_gates_tket.append(circ_tket.num_nonlocal_gates())
    num_2q_gates_tket2.append(circ_tket2.num_nonlocal_gates())
    num_2q_gates_tket3.append(circ_tket3.num_nonlocal_gates())
    depth_2q_qiskit.append(circ_qiskit.depth(lambda instr: instr.operation.num_qubits > 1))
    depth_2q_qiskit_opt.append(circ_qiskit_opt.depth(lambda instr: instr.operation.num_qubits > 1))
    depth_2q_tket.append(circ_tket.depth(lambda intr: intr.operation.num_qubits > 1))
    depth_2q_tket2.append(circ_tket2.depth(lambda intr: intr.operation.num_qubits > 1))
    depth_2q_tket3.append(circ_tket3.depth(lambda intr: intr.operation.num_qubits > 1))
# Out:
# fname: CH2_cmplt_BK_sto3g.qasm
# #2Q	 12632	 11655	 13200	 13494	 12078
# dep(2q)	 8865	 8272	 9142	 9142	 8061
# fname: CH2_cmplt_JW_sto3g.qasm
# #2Q	 15359	 14639	 13938	 14037	 14449
# dep(2q)	 10498	 10156	 9360	 9360	 9576
# fname: CH2_cmplt_P_sto3g.qasm
# #2Q	 21350	 20178	 17627	 17914	 16491
# dep(2q)	 13911	 13346	 11376	 11376	 10605
# fname: CH2_frz_BK_sto3g.qasm
# #2Q	 6249	 5783	 6505	 6476	 5868
# dep(2q)	 4654	 4356	 4695	 4695	 4173
# fname: CH2_frz_JW_sto3g.qasm
# #2Q	 7129	 6894	 6505	 6515	 6611
# dep(2q)	 5204	 5029	 4714	 4714	 4876
# fname: CH2_frz_P_sto3g.qasm
# #2Q	 8270	 7516	 8185	 8413	 7511
# dep(2q)	 5804	 5402	 5784	 5784	 5165
# fname: H2O_cmplt_BK_sto3g.qasm
# #2Q	 8980	 8274	 9407	 9206	 8105
# dep(2q)	 6302	 5886	 6261	 6261	 5606
# fname: H2O_cmplt_JW_sto3g.qasm
# #2Q	 10090	 9596	 9247	 9370	 9558
# dep(2q)	 7176	 6865	 6495	 6495	 6370
# fname: H2O_cmplt_P_sto3g.qasm
# #2Q	 15406	 14306	 13963	 13832	 13087
# dep(2q)	 9788	 9155	 9065	 9065	 8337
# fname: H2O_frz_BK_sto3g.qasm
# #2Q	 3949	 3774	 3760	 3592	 3156
# dep(2q)	 3016	 2900	 2691	 2691	 2318
# fname: H2O_frz_JW_sto3g.qasm
# #2Q	 5402	 5179	 4909	 5089	 5240
# dep(2q)	 4040	 3910	 3617	 3617	 3813
# fname: H2O_frz_P_sto3g.qasm
# #2Q	 7221	 6625	 7182	 7337	 6273
# dep(2q)	 4948	 4608	 4998	 4998	 4270
# fname: LiH_cmplt_BK_sto3g.qasm
# #2Q	 3910	 3742	 3609	 3669	 3264
# dep(2q)	 3093	 2985	 2824	 2824	 2464
# fname: LiH_cmplt_JW_sto3g.qasm
# #2Q	 5437	 5195	 4889	 4828	 4750
# dep(2q)	 4088	 3927	 3649	 3649	 3373
# fname: LiH_cmplt_P_sto3g.qasm
# #2Q	 6310	 5866	 6126	 6440	 5537
# dep(2q)	 4423	 4211	 4582	 4582	 3839
# fname: LiH_frz_BK_sto3g.qasm
# #2Q	 743	 698	 983	 1019	 647
# dep(2q)	 620	 573	 823	 823	 527
# fname: LiH_frz_JW_sto3g.qasm
# #2Q	 1066	 1000	 849	 920	 954
# dep(2q)	 875	 830	 733	 733	 784
# fname: LiH_frz_P_sto3g.qasm
# #2Q	 1311	 1236	 1227	 1302	 1228
# dep(2q)	 997	 932	 976	 976	 972
# fname: NH_cmplt_BK_sto3g.qasm
# #2Q	 3591	 3417	 3526	 3577	 3322
# dep(2q)	 2754	 2639	 2636	 2636	 2434
# fname: NH_cmplt_JW_sto3g.qasm
# #2Q	 5632	 5391	 5070	 5130	 5015
# dep(2q)	 4144	 3955	 3729	 3729	 3552
# fname: NH_cmplt_P_sto3g.qasm
# #2Q	 7550	 6969	 7194	 7365	 6715
# dep(2q)	 5319	 4934	 5182	 5182	 4618
# fname: NH_frz_BK_sto3g.qasm
# #2Q	 2458	 2260	 2751	 2882	 2383
# dep(2q)	 1930	 1795	 2160	 2160	 1813
# fname: NH_frz_JW_sto3g.qasm
# #2Q	 2500	 2381	 2370	 2415	 2269
# dep(2q)	 1900	 1806	 1869	 1869	 1770
# fname: NH_frz_P_sto3g.qasm
# #2Q	 2905	 2690	 3132	 3173	 2711
# dep(2q)	 2139	 1994	 2343	 2343	 1995

# %%
plt.figure(figsize=(15, 5))
ind = np.arange(len(fnames))
width = 0.17
plt.bar(ind - 2 * width, num_2q_gates_qiskit, width, label='Qiskit')
plt.bar(ind - width, num_2q_gates_qiskit_opt, width, label='Qiskit Opt')
plt.bar(ind, num_2q_gates_tket, width, label='Tket')
plt.bar(ind + width, num_2q_gates_tket2, width, label='Tket2')
plt.bar(ind + 2 * width, num_2q_gates_tket3, width, label='Tket3')
plt.xticks(ind, [fname.split('.')[0] for fname in fnames], rotation=45, fontweight='bold')
plt.xlim(-0.5, len(fnames))
plt.legend()
plt.tight_layout()
plt.show()
