# %%
import sys

sys.path.append('..')
from phoenix import Circuit
from qiskit import QuantumCircuit

# %%
origin_circ_file = '../benchmarks/hamlib100qasm/chemistry/all-vib-h2co-mu_y_prime_enc_unary_dvalues_16-16-16-16-16-16.qasm'
output_circ_file = './output/phoenix/chemistry/all-vib-h2co-mu_y_prime_enc_unary_dvalues_16-16-16-16-16-16.qasm'

circ_origin = Circuit.from_qasm(fname=origin_circ_file)
circ_output = Circuit.from_qasm(fname=output_circ_file)

# %%
circ_origin.to_qiskit().draw(output='mpl', fold=200)

# %%
circ_output.to_qiskit().draw(output='mpl', fold=200)
